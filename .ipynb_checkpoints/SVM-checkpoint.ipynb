# %%
from sklearn.datasets._samples_generator import make_blobs
from matplotlib import pyplot  as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

X,y=make_blobs(n_samples=125,centers=2,cluster_std=0.60,random_state=20)
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=20,random_state=0)
plt.scatter(train_X[:,0],train_X[:,1],c=train_y,cmap='winter')

svc=SVC(kernel='linear')
svc.fit(train_X,train_y)

plt.scatter(train_X[:,0],train_X[:,1],c=train_y,cmap='winter')

ax=plt.gca()
xlim=ax.get_xlim()

ax.scatter(train_X[:,0],train_X[:,1],c=test_y,cmap='winter',marker='s')

w=svc.coef_[0]
a=-w[0] / w[1]
xx=np.linspace(xlim[0],xlim[1])
yy=a *xx-(svc.intercept_[0] / w[1])
plt.plot(xx,yy)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4220             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4221                 colors = mcolors.to_rgba_array(c)
#    4222             except (TypeError, ValueError) as err:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     376     else:
# --> 377         rgba = np.array([to_rgba(cc) for cc in c])
#     378
#
# ...
